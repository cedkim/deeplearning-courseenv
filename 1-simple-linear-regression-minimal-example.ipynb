# %% [markdown]
# <a href="https://colab.research.google.com/gist/cedkim/47d8eec2c294c35080fc75d3fc5887f2/simple-linear-regression-minimal-example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Simple linear regression - minimal example

# %% [markdown]
# ## Import the relevant libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## Generate random input data to train on

# %%
observations = 1000

xs=np.random.uniform(low=-10,high=10,size=(observations,1))
zs=np.random.uniform(-10,10,(observations,1))

inputs = np.column_stack((xs,zs))

print(inputs.shape)
# Out:
# (1000, 2)

# %% [markdown]
# ## Create the targets we will aim at

# %%
noise = np.random.uniform(-1,1,(observations,1))

targets = 2*xs - 3*zs + 5 + noise

print(targets.shape)
# Out:
# (1000, 1)

# %% [markdown]
# ## Plot the training data

# %%
targets = targets.reshape(observations,)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(xs, zs, targets)
ax.set_xlabel('xs')
ax.set_ylabel('zs')
ax.set_zlabel('Targets')
ax.view_init(azim=100)
plt.show()
targets = targets.reshape(observations,1)

# %% [markdown]
# ## Initialize variables

# %%
init_range = 0.1

weights = np.random.uniform(-init_range,init_range,size=(2,1))

biases = np.random.uniform(-init_range,init_range,size=1)

print("Weight(s): \n" + str(weights))
print("Bias(es): \n" + str(biases))
# Out:
# Weight(s):
# [[-0.03034944]
#  [-0.06468269]]
# Bias(es):
# [0.00542423]

# %% [markdown]
# ## Set a learning rate

# %%
learning_rate = 0.02

# %% [markdown]
# ## Train the model

# %%
for i in range(100):
    outputs = np.dot(inputs,weights) + biases
    deltas = outputs - targets
    
    loss=np.sum(deltas ** 2) / 2 / observations

    print(loss)

    deltas_scaled = deltas / observations

    weights = weights - learning_rate * np.dot(inputs.T,deltas_scaled)
    biases = biases - learning_rate * np.sum(deltas_scaled)
# Out:
# 0.169442506080128
# 0.16944250606468314
# 0.16944250604984848
# 0.16944250603559977
# 0.1694425060219139
# 0.16944250600876878
# 0.16944250599614288
# 0.16944250598401567
# 0.1694425059723676
# 0.16944250596117963
# 0.1694425059504336
# 0.16944250594011215
# 0.16944250593019825
# 0.1694425059206762
# 0.16944250591153015
# 0.16944250590274543
# 0.16944250589430782
# 0.1694425058862035
# 0.1694425058784193
# 0.1694425058709425
# 0.1694425058637611
# 0.16944250585686352
# 0.16944250585023826
# 0.1694425058438748
# 0.16944250583776266
# 0.16944250583189205
# 0.1694425058262533
# 0.1694425058208373
# 0.16944250581563522
# 0.1694425058106387
# 0.16944250580583953
# 0.16944250580122996
# 0.16944250579680237
# 0.16944250579254966
# 0.16944250578846515
# 0.16944250578454198
# 0.16944250578077366
# 0.16944250577715422
# 0.16944250577367778
# 0.1694425057703387
# 0.16944250576713146
# 0.169442505764051
# 0.16944250576109215
# 0.16944250575825026
# 0.16944250575552056
# 0.1694425057528987
# ...

# %% [markdown]
# ## Print weights and biases and see if we have worked correctly

# %%
print(weights,biases)
# Out:
# [[ 1.99865522]
#  [-2.99721881]] [5.00080015]

# %% [markdown]
# ## Plot last outputs vs targets

# %%
plt.plot(outputs,targets)
plt.xlabel('outputs')
plt.ylabel('targets')
plt.show()
